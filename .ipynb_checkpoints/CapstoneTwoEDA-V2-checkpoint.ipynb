# %% [markdown]
# # House Price Prediction EDA

# %% [markdown]
# ### Due to the large number of independent variables, I will be focusing on ones with seemingly high importance, unique characteristics and relevance/irrelevance. The high dimensionality of this dataset will be more properly handeled in the pre-processing phase.

# %%
#Importing relevant packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
from datetime import datetime, date
import numpy as np
from numpy import mean
from numpy import std
from library.sb_utils import save_file
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# %%
data = pd.read_csv("Data Files/train_data_cleaned.csv")

# %%
#Setting the first column as our dependent variable.
first_column = data.pop('SalePrice')

# %%
data.insert(0, 'SalePrice', first_column)

# %%
data.shape
# Out:
# (1453, 79)

# %%
#Checking data types of our variables, we can see there are a large number of categorical and discrete variables
#in addition to a number of continuous ones.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SalePrice      1453 non-null   int64
#  1   MSSubClass     1453 non-null   int64
#  2   MSZoning       1453 non-null   object
#  3   LotFrontage    1453 non-null   float64
#  4   LotArea        1453 non-null   int64
#  5   Street         1453 non-null   object
#  6   Alley          1453 non-null   object
#  7   LotShape       1453 non-null   object
#  8   LandContour    1453 non-null   object
#  9   Utilities      1453 non-null   object
#  10  LotConfig      1453 non-null   object
#  11  LandSlope      1453 non-null   object
#  12  Neighborhood   1453 non-null   object
#  13  Condition1     1453 non-null   object
#  14  Condition2     1453 non-null   object
#  15  BldgType       1453 non-null   object
#  16  HouseStyle     1453 non-null   object
#  17  OverallQual    1453 non-null   int64
#  18  OverallCond    1453 non-null   int64
#  19  RoofStyle      1453 non-null   object
#  20  RoofMatl       1453 non-null   object
#  21  Exterior1st    1453 non-null   object
#  22  Exterior2nd    1453 non-null   object
#  23  MasVnrType     1453 non-null   object
#  24  MasVnrArea     1453 non-null   float64
#  25  ExterQual      1453 non-null   object
#  26  ExterCond      1453 non-null   object
#  27  Foundation     1453 non-null   object
#  28  BsmtQual       1453 non-null   object
#  29  BsmtCond       1453 non-null   object
#  30  BsmtExposure   1453 non-null   object
#  31  BsmtFinType1   1453 non-null   object
#  32  BsmtFinSF1     1453 non-null   int64
#  33  BsmtFinType2   1453 non-null   object
#  34  BsmtFinSF2     1453 non-null   int64
#  35  BsmtUnfSF      1453 non-null   int64
#  36  TotalBsmtSF    1453 non-null   int64
#  37  Heating        1453 non-null   object
#  38  HeatingQC      1453 non-null   object
#  39  CentralAir     1453 non-null   object
#  40  Electrical     1453 non-null   object
#  41  1stFlrSF       1453 non-null   int64
#  42  2ndFlrSF       1453 non-null   int64
#  43  LowQualFinSF   1453 non-null   int64
#  44  GrLivArea      1453 non-null   int64
#  45  BsmtFullBath   1453 non-null   int64
#  46  BsmtHalfBath   1453 non-null   int64
#  47  FullBath       1453 non-null   int64
#  48  HalfBath       1453 non-null   int64
#  49  BedroomAbvGr   1453 non-null   int64
#  50  KitchenAbvGr   1453 non-null   int64
#  51  KitchenQual    1453 non-null   object
#  52  TotRmsAbvGrd   1453 non-null   int64
#  53  Functional     1453 non-null   object
#  54  Fireplaces     1453 non-null   int64
#  55  FireplaceQu    1453 non-null   object
#  56  GarageType     1453 non-null   object
#  57  GarageFinish   1453 non-null   object
#  58  GarageCars     1453 non-null   int64
#  59  GarageArea     1453 non-null   int64
#  60  GarageQual     1453 non-null   object
#  61  GarageCond     1453 non-null   object
#  62  PavedDrive     1453 non-null   object
#  63  WoodDeckSF     1453 non-null   int64
#  64  OpenPorchSF    1453 non-null   int64
#  65  EnclosedPorch  1453 non-null   int64
#  66  3SsnPorch      1453 non-null   int64
#  67  ScreenPorch    1453 non-null   int64
#  68  PoolArea       1453 non-null   int64
#  69  PoolQC         1453 non-null   object
#  70  Fence          1453 non-null   object
#  71  MiscFeature    1453 non-null   object
#  72  MiscVal        1453 non-null   int64
#  73  SaleType       1453 non-null   object
#  74  SaleCondition  1453 non-null   object
#  75  Age_of_sale    1453 non-null   int64
#  76  House_Age      1453 non-null   int64
#  77  Remod_Age      1453 non-null   int64
#  78  Garage_Age     1453 non-null   float64
# dtypes: float64(3), int64(33), object(43)
# memory usage: 896.9+ KB

# %%
plt.hist(data['SalePrice'], bins=20)
# Out:
# (array([ 22., 126., 380., 342., 228., 142.,  85.,  48.,  28.,  22.,  12.,
#           7.,   3.,   1.,   2.,   1.,   2.,   0.,   0.,   2.]),
#  array([ 34900.,  70905., 106910., 142915., 178920., 214925., 250930.,
#         286935., 322940., 358945., 394950., 430955., 466960., 502965.,
#         538970., 574975., 610980., 646985., 682990., 718995., 755000.]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ### Assessing Categorical Variables

# %%
#Should data be grouped by or summarized by neighborhood?
neighborhood_price_means = data.groupby('Neighborhood')[['SalePrice']].mean()
print(neighborhood_price_means)
# Out:
#                   SalePrice
# Neighborhood
# Blmngtn       194870.882353
# Blueste       137500.000000
# BrDale        104493.750000
# BrkSide       124834.051724
# ClearCr       206647.384615
# CollgCr       197965.773333
# Crawfor       210624.725490
# Edwards       128219.700000
# Gilbert       192854.506329
# IDOTRR        100123.783784
# MeadowV        98576.470588
# Mitchel       156270.122449
# NAmes         145421.941704
# NPkVill       142694.444444
# NWAmes        189050.068493
# NoRidge       335295.317073
# NridgHt       316270.623377
# OldTown       128225.300885
# SWISU         142591.360000
# Sawyer        136064.273973
# SawyerW       186555.796610
# Somerst       225379.837209
# StoneBr       310499.000000
# Timber        238929.250000
# Veenker       238772.727273

# %%
(neighborhood_price_means.sort_values(by='SalePrice')).plot(kind='barh',figsize=(10,10), 
                                                            title='Average Home Sale Price by Neighborhood')
# Out:
# <AxesSubplot:title={'center':'Average Home Sale Price by Neighborhood'}, ylabel='Neighborhood'>

# %% [markdown]
# There is clearly a correlation between neighborhood and sale price

# %%
#Creating a seperate dataframe for categorical variables
data_cat = data.select_dtypes(include='object').copy().join(data[{'MSSubClass', 'OverallQual', 'OverallCond','SalePrice'}])

# %%
data_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 47 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1453 non-null   object
#  1   Street         1453 non-null   object
#  2   Alley          1453 non-null   object
#  3   LotShape       1453 non-null   object
#  4   LandContour    1453 non-null   object
#  5   Utilities      1453 non-null   object
#  6   LotConfig      1453 non-null   object
#  7   LandSlope      1453 non-null   object
#  8   Neighborhood   1453 non-null   object
#  9   Condition1     1453 non-null   object
#  10  Condition2     1453 non-null   object
#  11  BldgType       1453 non-null   object
#  12  HouseStyle     1453 non-null   object
#  13  RoofStyle      1453 non-null   object
#  14  RoofMatl       1453 non-null   object
#  15  Exterior1st    1453 non-null   object
#  16  Exterior2nd    1453 non-null   object
#  17  MasVnrType     1453 non-null   object
#  18  ExterQual      1453 non-null   object
#  19  ExterCond      1453 non-null   object
#  20  Foundation     1453 non-null   object
#  21  BsmtQual       1453 non-null   object
#  22  BsmtCond       1453 non-null   object
#  23  BsmtExposure   1453 non-null   object
#  24  BsmtFinType1   1453 non-null   object
#  25  BsmtFinType2   1453 non-null   object
#  26  Heating        1453 non-null   object
#  27  HeatingQC      1453 non-null   object
#  28  CentralAir     1453 non-null   object
#  29  Electrical     1453 non-null   object
#  30  KitchenQual    1453 non-null   object
#  31  Functional     1453 non-null   object
#  32  FireplaceQu    1453 non-null   object
#  33  GarageType     1453 non-null   object
#  34  GarageFinish   1453 non-null   object
#  35  GarageQual     1453 non-null   object
#  36  GarageCond     1453 non-null   object
#  37  PavedDrive     1453 non-null   object
#  38  PoolQC         1453 non-null   object
#  39  Fence          1453 non-null   object
#  40  MiscFeature    1453 non-null   object
#  41  SaleType       1453 non-null   object
#  42  SaleCondition  1453 non-null   object
#  43  OverallQual    1453 non-null   int64
#  44  SalePrice      1453 non-null   int64
#  45  OverallCond    1453 non-null   int64
#  46  MSSubClass     1453 non-null   int64
# dtypes: int64(4), object(43)
# memory usage: 533.6+ KB

# %%
def stripplots(column):
    sns.catplot(x=column, y='SalePrice', kind="strip", data=data_cat)

# %%
def swarmplots(column):
    sns.catplot(x=column, y='SalePrice', kind="swarm", data=data_cat)

# %%
sns.countplot(data=data_cat, x='OverallQual')
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='count'>

# %%
#Zoning countplot shows almost all observations are residential, with a majority being low-density
sns.countplot(data=data_cat, x='MSZoning')
# Out:
# <AxesSubplot:xlabel='MSZoning', ylabel='count'>

# %%
#Integer values given to generally classify dwelling types (ex: '1-STORY 1945 & OLDER')
sns.countplot(x='MSSubClass', data=data)
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='count'>

# %%
stripplots('Utilities')

# %%
#There is only one instance of the NoSeWa utilities being used, so we can remove this column from our dataset
del data['Utilities']
del data_cat['Utilities']

# %%
#Quality of the entire dwelling, subjective but also seems to have high correlation with sale price, perhaps semi-log relation
stripplots('OverallQual')

# %%
#semi-log boxplot of OverallQual
sns.boxplot(x='OverallQual', y='SalePrice', data=data).set(yscale="log")
# Out:
# [None]

# %%
stripplots("OverallCond")

# %% [markdown]
# There are a number of attributes attributed to feature qualities and conditions

# %% [markdown]
# There are many other similar quality attributes, are they necessary, do any have a stronger correlation or can they be omitted?

# %% [markdown]
# ###  Principle Component Analysis (PCA)

# %% [markdown]
# #### Visualization of high dimensional data

# %% [markdown]
# There are many other similar quality attributes, are they necessary, do any have a stronger correlation or can they be omitted? Possible PCA analysis groupings: Condition/quality (of home/garage/basement/interior vs exterior etc.), number of rooms/bath rooms, exterior/lot factors and proximities (street style, driveway, proximity to train tracks, etc.), home/lot style and sublasses/zonings/neighborhood, stylistic features (roof/exterior type/material/style, etc.)

# %% [markdown]
# HOW TO HANDLE HIGH DIMENSIONAL CATEGORICAL DATA

# %% [markdown]
# ## Assessing Continuous/Numerical Variables

# %%
data_num = data.select_dtypes(include=['int64','float64']).copy()
data_num = data_num.drop(columns=['MSSubClass','OverallQual','OverallCond'])

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 33 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SalePrice      1453 non-null   int64
#  1   LotFrontage    1453 non-null   float64
#  2   LotArea        1453 non-null   int64
#  3   MasVnrArea     1453 non-null   float64
#  4   BsmtFinSF1     1453 non-null   int64
#  5   BsmtFinSF2     1453 non-null   int64
#  6   BsmtUnfSF      1453 non-null   int64
#  7   TotalBsmtSF    1453 non-null   int64
#  8   1stFlrSF       1453 non-null   int64
#  9   2ndFlrSF       1453 non-null   int64
#  10  LowQualFinSF   1453 non-null   int64
#  11  GrLivArea      1453 non-null   int64
#  12  BsmtFullBath   1453 non-null   int64
#  13  BsmtHalfBath   1453 non-null   int64
#  14  FullBath       1453 non-null   int64
#  15  HalfBath       1453 non-null   int64
#  16  BedroomAbvGr   1453 non-null   int64
#  17  KitchenAbvGr   1453 non-null   int64
#  18  TotRmsAbvGrd   1453 non-null   int64
#  19  Fireplaces     1453 non-null   int64
#  20  GarageCars     1453 non-null   int64
#  21  GarageArea     1453 non-null   int64
#  22  WoodDeckSF     1453 non-null   int64
#  23  OpenPorchSF    1453 non-null   int64
#  24  EnclosedPorch  1453 non-null   int64
#  25  3SsnPorch      1453 non-null   int64
#  26  ScreenPorch    1453 non-null   int64
#  27  PoolArea       1453 non-null   int64
#  28  MiscVal        1453 non-null   int64
#  29  Age_of_sale    1453 non-null   int64
#  30  House_Age      1453 non-null   int64
#  31  Remod_Age      1453 non-null   int64
#  32  Garage_Age     1453 non-null   float64
# dtypes: float64(3), int64(30)
# memory usage: 374.7 KB

# %%
data_num.describe().T
# Out:
#                 count           mean           std      min       25%  \
# SalePrice      1453.0  180581.896765  79339.590536  34900.0  129900.0
# LotFrontage    1453.0      57.677908     34.362266      0.0      43.0
# LotArea        1453.0   10078.068823   5635.138562   1300.0    7535.0
# MasVnrArea     1453.0     103.046800    180.689754      0.0       0.0
# BsmtFinSF1     1453.0     441.349621    455.455848      0.0       0.0
# BsmtFinSF2     1453.0      45.836201    160.292839      0.0       0.0
# BsmtUnfSF      1453.0     568.179628    442.379812      0.0     224.0
# TotalBsmtSF    1453.0    1055.365451    438.153036      0.0     795.0
# 1stFlrSF       1453.0    1160.931177    386.083379    334.0     882.0
# 2ndFlrSF       1453.0     346.264969    435.704868      0.0       0.0
# LowQualFinSF   1453.0       5.602891     47.672897      0.0       0.0
# GrLivArea      1453.0    1512.799036    523.516350    334.0    1128.0
# BsmtFullBath   1453.0       0.423262      0.516060      0.0       0.0
# BsmtHalfBath   1453.0       0.056435      0.236731      0.0       0.0
# FullBath       1453.0       1.563661      0.551333      0.0       1.0
# HalfBath       1453.0       0.383345      0.501703      0.0       0.0
# BedroomAbvGr   1453.0       2.865107      0.815467      0.0       2.0
# KitchenAbvGr   1453.0       1.046111      0.219426      0.0       1.0
# TotRmsAbvGrd   1453.0       6.513421      1.620926      2.0       5.0
# Fireplaces     1453.0       0.609085      0.641731      0.0       0.0
# GarageCars     1453.0       1.766690      0.748694      0.0       1.0
# GarageArea     1453.0     472.598073    213.946218      0.0     330.0
# WoodDeckSF     1453.0      93.869236    124.393967      0.0       0.0
# OpenPorchSF    1453.0      46.757054     66.360374      0.0       0.0
# EnclosedPorch  1453.0      21.580179     59.563760      0.0       0.0
# 3SsnPorch      1453.0       3.426015     29.386956      0.0       0.0
# ScreenPorch    1453.0      15.133517     55.881824      0.0       0.0
# PoolArea       1453.0       2.419821     37.990157      0.0       0.0
# MiscVal        1453.0      26.492774    187.371449      0.0       0.0
# Age_of_sale    1453.0    4873.892636    480.489596   4057.0    4452.0
# House_Age      1453.0      49.673778     30.238553     11.0      20.0
# Remod_Age      1453.0      36.140399     20.665301     11.0      17.0
# Garage_Age     1453.0      40.031659     25.881332      0.0      18.0
#
#                     50%       75%       max
# SalePrice      162900.0  213500.0  755000.0
# LotFrontage        63.0      79.0     313.0
# LotArea          9453.0   11526.0   70761.0
# MasVnrArea          0.0     164.0    1600.0
# BsmtFinSF1        380.0     708.0    5644.0
# BsmtFinSF2          0.0       0.0    1474.0
# BsmtUnfSF         480.0     810.0    2336.0
# TotalBsmtSF       990.0    1291.0    6110.0
# 1stFlrSF         1086.0    1390.0    4692.0
# 2ndFlrSF            0.0     728.0    2065.0
# LowQualFinSF        0.0       0.0     572.0
# GrLivArea        1458.0    1774.0    5642.0
# BsmtFullBath        0.0       1.0       3.0
# BsmtHalfBath        0.0       0.0       2.0
# FullBath            2.0       2.0       3.0
# HalfBath            0.0       1.0       2.0
# BedroomAbvGr        3.0       3.0       8.0
# KitchenAbvGr        1.0       1.0       3.0
# TotRmsAbvGrd        6.0       7.0      14.0
# Fireplaces          1.0       1.0       3.0
# GarageCars          2.0       2.0       4.0
# GarageArea        479.0     576.0    1418.0
# WoodDeckSF          0.0     168.0     857.0
# OpenPorchSF        25.0      68.0     547.0
# EnclosedPorch       0.0       0.0     386.0
# 3SsnPorch           0.0       0.0     508.0
# ScreenPorch         0.0       0.0     480.0
# PoolArea            0.0       0.0     738.0
# MiscVal             0.0       0.0    3500.0
# Age_of_sale      4848.0    5244.0    5699.0
# House_Age          48.0      67.0     149.0
# Remod_Age          27.0      54.0      71.0
# Garage_Age         36.0      59.0     121.0

# %% [markdown]
# Noteworthy takeaways: total rooms has a max value of 14,

# %% [markdown]
# ### PCA for numerical variables

# %% [markdown]
# All data values are homogenous with regards to square footage (SF), except for LotFrontage, which is in units of linear feet, MiscVal which is a dollar amount and the three related to age (House_Age, Remod_Age and Garage_Age).
# We will attempt to scale the data and perform PCA on the results

# %% [markdown]
# #### Scale the data

# %%
data_num.head()
# Out:
#    SalePrice  LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 0     208500         65.0     8450       196.0         706           0
# 1     181500         80.0     9600         0.0         978           0
# 2     223500         68.0    11250       162.0         486           0
# 3     140000         60.0     9550         0.0         216           0
# 4     250000         84.0    14260       350.0         655           0
#
#    BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  ...  OpenPorchSF  \
# 0        150          856       856       854  ...           61
# 1        284         1262      1262         0  ...            0
# 2        434          920       920       866  ...           42
# 3        540          756       961       756  ...           35
# 4        490         1145      1145      1053  ...           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  Age_of_sale  \
# 0              0          0            0         0        0         4938
# 1              0          0            0         0        0         5214
# 2              0          0            0         0        0         4725
# 3            272          0            0         0        0         5668
# 4              0          0            0         0        0         4634
#
#    House_Age  Remod_Age  Garage_Age
# 0         18         18        18.0
# 1         45         45        45.0
# 2         20         19        20.0
# 3        106         51        23.0
# 4         21         21        21.0
#
# [5 rows x 33 columns]

# %% [markdown]
# Data already has a numerical index.

# %%
data_num_columns = data_num.columns

# %%
data_num_scale = scale(data_num)

# %%
data_num_scale_df = pd.DataFrame(data_num_scale, columns=data_num_columns).drop(columns=['SalePrice'])

# %%
data_num_scale_df.head()
# Out:
#    LotFrontage   LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0     0.213159 -0.289013    0.514612    0.581267   -0.286051  -0.945621
# 1     0.649834 -0.084866   -0.570493    1.178677   -0.286051  -0.642609
# 2     0.300494  0.208040    0.326380    0.098068   -0.286051  -0.303418
# 3     0.067600 -0.093742   -0.570493   -0.494949   -0.286051  -0.063722
# 4     0.766281  0.742372    1.367196    0.469253   -0.286051  -0.176786
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  ...  OpenPorchSF  \
# 0    -0.455170 -0.790078  1.165720     -0.117568  ...     0.214704
# 1     0.471766  0.261870 -0.794997     -0.117568  ...    -0.704836
# 2    -0.309052 -0.624254  1.193271     -0.117568  ...    -0.071710
# 3    -0.683479 -0.518023  0.940720     -0.117568  ...    -0.177231
# 4     0.204644 -0.041278  1.622608     -0.117568  ...     0.561416
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  Age_of_sale  \
# 0      -0.362429  -0.116623    -0.270906 -0.063718 -0.14144     0.133467
# 1      -0.362429  -0.116623    -0.270906 -0.063718 -0.14144     0.708079
# 2      -0.362429  -0.116623    -0.270906 -0.063718 -0.14144    -0.309984
# 3       4.205679  -0.116623    -0.270906 -0.063718 -0.14144     1.653274
# 4      -0.362429  -0.116623    -0.270906 -0.063718 -0.14144    -0.499439
#
#    House_Age  Remod_Age  Garage_Age
# 0  -1.047824  -0.878121   -0.851550
# 1  -0.154617   0.428866    0.192032
# 2  -0.981661  -0.829715   -0.774247
# 3   1.863370   0.719308   -0.658294
# 4  -0.948579  -0.732901   -0.735596
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Verifying the scaling

# %%
data_num_scale_df.mean()
# Out:
# LotFrontage      5.883494e-17
# LotArea          6.115348e-17
# MasVnrArea      -3.361997e-18
# BsmtFinSF1      -2.085966e-17
# BsmtFinSF2       1.155304e-16
# BsmtUnfSF        2.506216e-17
# TotalBsmtSF      1.463233e-17
# 1stFlrSF         1.595611e-16
# 2ndFlrSF         3.835733e-17
# LowQualFinSF     2.217008e-16
# GrLivArea       -1.742508e-16
# BsmtFullBath     1.806309e-16
# BsmtHalfBath    -5.119404e-17
# FullBath        -6.785121e-17
# HalfBath        -2.597907e-18
# BedroomAbvGr    -1.859987e-16
# KitchenAbvGr    -2.746522e-16
# TotRmsAbvGrd    -2.261707e-16
# Fireplaces      -4.156651e-17
# GarageCars       4.003833e-17
# GarageArea       3.957987e-17
# WoodDeckSF      -8.863446e-17
# OpenPorchSF      2.101248e-18
# EnclosedPorch    3.870117e-17
# 3SsnPorch       -5.433445e-16
# ScreenPorch     -1.488448e-16
# PoolArea        -5.636120e-16
# MiscVal          1.213757e-16
# Age_of_sale     -1.954161e-16
# House_Age        1.017959e-16
# Remod_Age       -1.253108e-16
# Garage_Age      -1.166766e-16
# dtype: float64

# %%
data_num_scale_df.std(ddof=0)
# Out:
# LotFrontage      1.0
# LotArea          1.0
# MasVnrArea       1.0
# BsmtFinSF1       1.0
# BsmtFinSF2       1.0
# BsmtUnfSF        1.0
# TotalBsmtSF      1.0
# 1stFlrSF         1.0
# 2ndFlrSF         1.0
# LowQualFinSF     1.0
# GrLivArea        1.0
# BsmtFullBath     1.0
# BsmtHalfBath     1.0
# FullBath         1.0
# HalfBath         1.0
# BedroomAbvGr     1.0
# KitchenAbvGr     1.0
# TotRmsAbvGrd     1.0
# Fireplaces       1.0
# GarageCars       1.0
# GarageArea       1.0
# WoodDeckSF       1.0
# OpenPorchSF      1.0
# EnclosedPorch    1.0
# 3SsnPorch        1.0
# ScreenPorch      1.0
# PoolArea         1.0
# MiscVal          1.0
# Age_of_sale      1.0
# House_Age        1.0
# Remod_Age        1.0
# Garage_Age       1.0
# dtype: float64

# %% [markdown]
# #### Calculate PCA transformation

# %%
num_pca = PCA().fit(data_num_scale)

# %%
plt.subplots(figsize=(10, 6))
plt.plot(num_pca.explained_variance_ratio_.cumsum())
plt.xlabel('Component #')
plt.ylabel('Cumulative ratio variance')
plt.title('Cumulative variance ratio explained by PCA components for numerical statistics');

# %% [markdown]
# The first 12 compnents (50%) explain 80% of the variance.

# %%
num_pca_x = num_pca.transform(data_num_scale)

# %%
num_pca_x.shape
# Out:
# (1453, 33)

# %% [markdown]
# ### PCA Visualization

# %%
# define useful function to create scatterplots of ticket prices against desired columns
def scatterplots(columns, ncol=None, figsize=(15, 8)):
    if ncol is None:
        ncol = len(columns)
    nrow = int(np.ceil(len(columns) / ncol))
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.5, hspace=0.6)
    for i, col in enumerate(columns):
        ax = axes.flatten()[i]
        ax.scatter(x = col, y = 'SalePrice', data=data_num, alpha=0.5)
        ax.set(xlabel=col, ylabel='Sale Price')
    nsubplots = nrow * ncol    
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)

# %%
num_features = [x for x in data_num.columns if x not in ['SalePrice']]

# %%
scatterplots(num_features, ncol=4, figsize=(15,15))

# %% [markdown]
# Seems DV's relationship to age-based variables is maybe logarithmic. Also worth noting is that extreme values of certain room attributes result in lower property values. Sales price declines with more than 1 half bathroom, 1 basement full bath, 4 above ground bedrooms, 1 above ground kitchen, 2 fireplaces, and 3 car garages. This relationship isn't entirely represented in TotRmsAbvGrd, however. Certain other intuitive relationships exist as well, such as finished versus unfished area. We would expect finished basements to generate more value, and the plots show that higher finished basement square footage lead to greater value than unfinished basements. A few interesting outliers seem to be present as well, such as the extreme value seen in BsmtFinSF1, 1stFlrSF as well as a house with 3 full baths in the basement and another (or the same) with 8 above ground bedrooms.

# %%
#The outlier for BedroomAbvGr is not the same as the BsmtFullBath
print(data_num[data_num['BedroomAbvGr']==8]['BsmtFullBath'])
# Out:
# 630    0
# Name: BsmtFullBath, dtype: int64

# %%
# The outlier for BsmtFinSF1 IS the same house as the outlier for 1stFlrSF AND TotalBsmtSF, which makes sense
print(data_num[data_num['BsmtFinSF1']>4000][['1stFlrSF','TotalBsmtSF']])
# Out:
#       1stFlrSF  TotalBsmtSF
# 1291      4692         6110

# %% [markdown]
# Should these outliers be omitted?

# %% [markdown]
# The value of certain attributes don't necessarily indicate an increase in value, such as area of the different porch types or pool areas, but perhaps houses that have these attributes are worth more than ones that don't?

# %%
fig, ax = plt.subplots(5,1, sharey=True)
fig.set_size_inches([12,20])
fig.subplots_adjust(wspace=0.5, hspace=0.3)

ax[0].scatter(data_num['TotRmsAbvGrd'], data_num['SalePrice'])
ax[0].set_xlabel("Total # Rooms Above Ground")
ax[0].set_ylabel("Sale Price ($)")

ax[1].scatter(data_num['BedroomAbvGr'], data_num['SalePrice'])
ax[1].set_xlabel("Total Bedrooms Above Ground")
ax[1].set_ylabel("Sale Price ($)")

ax[2].scatter(data_num['KitchenAbvGr'], data_num['SalePrice'])
ax[2].set_xlabel("Total Kitchens Above Ground")
ax[2].set_ylabel("Sale Price ($)")

ax[3].scatter(data_num['FullBath'], data_num['SalePrice'])
ax[3].set_xlabel("Full Bathrooms")
ax[3].set_ylabel("Sale Price ($)")

ax[4].scatter(data_num['HalfBath'], data_num['SalePrice'])
ax[4].set_xlabel("Half Bathrooms")
ax[4].set_ylabel("Sale Price ($)")

plt.show()

# %%
fig, ax = plt.subplots(3,1, sharey=True)
fig.set_size_inches([10,15])

ax[0].scatter(data_num['House_Age'], data_num['SalePrice'])
ax[0].set_xlabel("House Age")
ax[0].set_ylabel("Sale Price ($)")
ax[0].set_yscale("log")
ax[0].set_xscale("log")

ax[1].scatter(data_num['Remod_Age'], data_num['SalePrice'])
ax[1].set_xlabel("Remodel Age")
ax[1].set_ylabel("Sale Price ($)")
ax[1].set_yscale("log")
ax[1].set_xscale("log")

ax[2].scatter(data_num['Garage_Age'], data_num['SalePrice'])
ax[2].set_xlabel("Garage Age")
ax[2].set_ylabel("Sale Price ($)")
ax[2].set_yscale("log")

plt.show()

# %% [markdown]
# We notice a log-log relationship between these age attributes and sale price. Garage Age has a large number of zero values for houses without garages, so it is plotted on a semi-log scale.

# %%
#Huge number of remodels occured in 1950? Should these be included?
data.Remod_Age.value_counts()
# Out:
# 71    178
# 15     96
# 14     76
# 16     73
# 17     62
#      ...
# 11      6
# 38      5
# 35      5
# 69      5
# 70      4
# Name: Remod_Age, Length: 61, dtype: int64

# %% [markdown]
#  We also noticed a large, questionable number of remodels occuring 71 years ago, or in 1950. What is the significance of this and is it of concern?

# %%
plt.subplots(figsize=(12,10))
sns.heatmap(data.corr());

# %%
# Make a heatmap of the data 
plt.figure(figsize=(20,20))
sns.heatmap(data_num.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Frome the heatmap we can see that LotArea, OverallQual, TotalBsmtSF, 1stFlrSF. 2ndFlrSF, GrLivArea, FullBath, HalfBath, TotRmsAbvGrd, Fireplaces, GarageCars, Garage Area, WoodDeckSF, OpenPorchSF, House_Age and Remod_Age have the strongest correlations to SalePrice
#
# Should Square Footage areas be grouped, i.e.: Total house SF, basement SF, porch SF, garage SF and lot SF?

# %%
data_num.hist()x
# Out:
# array([[<AxesSubplot:title={'center':'SalePrice'}>,
#         <AxesSubplot:title={'center':'LotFrontage'}>,
#         <AxesSubplot:title={'center':'LotArea'}>,
#         <AxesSubplot:title={'center':'MasVnrArea'}>,
#         <AxesSubplot:title={'center':'BsmtFinSF1'}>,
#         <AxesSubplot:title={'center':'BsmtFinSF2'}>],
#        [<AxesSubplot:title={'center':'BsmtUnfSF'}>,
#         <AxesSubplot:title={'center':'TotalBsmtSF'}>,
#         <AxesSubplot:title={'center':'1stFlrSF'}>,
#         <AxesSubplot:title={'center':'2ndFlrSF'}>,
#         <AxesSubplot:title={'center':'LowQualFinSF'}>,
#         <AxesSubplot:title={'center':'GrLivArea'}>],
#        [<AxesSubplot:title={'center':'BsmtFullBath'}>,
#         <AxesSubplot:title={'center':'BsmtHalfBath'}>,
#         <AxesSubplot:title={'center':'FullBath'}>,
#         <AxesSubplot:title={'center':'HalfBath'}>,
#         <AxesSubplot:title={'center':'BedroomAbvGr'}>,
#         <AxesSubplot:title={'center':'KitchenAbvGr'}>],
#        [<AxesSubplot:title={'center':'TotRmsAbvGrd'}>,
#         <AxesSubplot:title={'center':'Fireplaces'}>,
#         <AxesSubplot:title={'center':'GarageCars'}>,
#         <AxesSubplot:title={'center':'GarageArea'}>,
#         <AxesSubplot:title={'center':'WoodDeckSF'}>,
#         <AxesSubplot:title={'center':'OpenPorchSF'}>],
#        [<AxesSubplot:title={'center':'EnclosedPorch'}>,
#         <AxesSubplot:title={'center':'3SsnPorch'}>,
#         <AxesSubplot:title={'center':'ScreenPorch'}>,
#         <AxesSubplot:title={'center':'PoolArea'}>,
#         <AxesSubplot:title={'center':'MiscVal'}>,
#         <AxesSubplot:title={'center':'Age_of_sale'}>],
#        [<AxesSubplot:title={'center':'House_Age'}>,
#         <AxesSubplot:title={'center':'Remod_Age'}>,
#         <AxesSubplot:title={'center':'Garage_Age'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
